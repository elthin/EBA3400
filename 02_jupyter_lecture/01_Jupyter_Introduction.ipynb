# %% [markdown]
# # Exercise

# %% [markdown]
# ## (1) Show text

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## (2) add two numbers

# %%
x = 2
y = 4

# %%
print( x + y)
# Out:
# 6
