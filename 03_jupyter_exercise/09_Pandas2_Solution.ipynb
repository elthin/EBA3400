# %% [markdown]
# # Pandas 2 - Data Preprocessing

# %%
# Import package
import pandas as pd

# %% [markdown]
# ## (1) Basic operations and data consolidation

# %% [markdown]
# **(1.1) Use the following series to create a data frame named <code>score_df</code>, as shown below.**<br>
# Hint: Rename columns https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html

# %% [markdown]
# ||score1|score2|score3|
# |:-:|:-:|:-:|:-:|
# |**S01**|7.0|8.5|7.5|
# |**S02**|6.5|7.5|7.0|
# |**S03**|8.0|7.5|8.0|
# |**S04**|6.0|8.0|8.5|

# %%
s1 = pd.Series([7.0,6.5,8.0,6.0], index =  ["S01","S02","S03","S04"])
s2 = pd.Series([8.5,7.5,7.5,8.0], index =  ["S01","S02","S03","S04"])
s3 = pd.Series([7.5,7.0,8.0,8.5], index =  ["S01","S02","S03","S04"])

# %%
# put your code here
score_df = pd.concat([s1,s2,s3], axis = 1)
score_df.rename(columns = {0:"score1",1:"score2",2:"score3"}, inplace = True)
score_df
# Out:
#      score1  score2  score3
# S01     7.0     8.5     7.5
# S02     6.5     7.5     7.0
# S03     8.0     7.5     8.0
# S04     6.0     8.0     8.5

# %% [markdown]
# **(1.2) Calculate the average score of each student and add their average score to a new column called <code>avg_score</code>. Round the number to two decimal places.**<br>
# Hint: <code>dataframe.mean(axis=1)</code><br>
# Example: The average score of student "S01" is (7.0+8.5+7.5)/3 = 7.67

# %%
# put your code here
score_df['avg_score'] = round(score_df.mean(axis = 1),2)
score_df
# Out:
#      score1  score2  score3  avg_score
# S01     7.0     8.5     7.5       7.67
# S02     6.5     7.5     7.0       7.00
# S03     8.0     7.5     8.0       7.83
# S04     6.0     8.0     8.5       7.50

# %% [markdown]
# **(1.3) Use the following data to create a dataframe named <code>product_df</code>.** <br>
# Hint: <br>
# Use the argument <code>columns</code> to assign a list of column names. <br>
# <code>df = pd.DataFrame(nested_list, columns = column_name_list)</code>

# %%
name_list = ["product_category","product_name"]
product_list = [["beverage","coffee"],["dairy","cheeses"],["meat","beef"],["meat","pork"],["beverage", "tea"],["dairy","yogurt"],["beverage", "soda"],["dairy","milk"]]

# %%
# put your code here
product_df = pd.DataFrame(product_list, columns = name_list)
product_df
# Out:
#   product_category product_name
# 0         beverage       coffee
# 1            dairy      cheeses
# 2             meat         beef
# 3             meat         pork
# 4         beverage          tea
# 5            dairy       yogurt
# 6         beverage         soda
# 7            dairy         milk

# %% [markdown]
# **(1.4) Sort the <code>product_df</code> alphabetically by <code>product_category</code>. Apply this change directly to the dataframe.**

# %%
# put your code here
product_df.sort_values(by = "product_category", inplace = True)
product_df
# Out:
#   product_category product_name
# 0         beverage       coffee
# 4         beverage          tea
# 6         beverage         soda
# 1            dairy      cheeses
# 5            dairy       yogurt
# 7            dairy         milk
# 2             meat         beef
# 3             meat         pork

# %% [markdown]
# **(1.5) Rest the index of <code>product_df</code>. Apply this change directly to the dataframe.**

# %%
# put your code here
product_df.reset_index(drop = True, inplace = True)
product_df
# Out:
#   product_category product_name
# 0         beverage       coffee
# 1         beverage          tea
# 2         beverage         soda
# 3            dairy      cheeses
# 4            dairy       yogurt
# 5            dairy         milk
# 6             meat         beef
# 7             meat         pork

# %% [markdown]
# **(1.6) Given the following dataframe, find the price of each product in <code>product_df</code>.**

# %%
price_df = pd.DataFrame({"product_name":["beef","bread","cheeses","chicken","coffee","egg","ham","milk","pork","soda","tea","yogurt"],
           "price":[89, 39, 69, 79, 49, 29, 59, 29, 59, 29, 49, 29]})

# %%
# put your code here
pd.merge(product_df, price_df, how = "left", on = "product_name")
# Out:
#   product_category product_name  price
# 0         beverage       coffee     49
# 1         beverage          tea     49
# 2         beverage         soda     29
# 3            dairy      cheeses     69
# 4            dairy       yogurt     29
# 5            dairy         milk     29
# 6             meat         beef     89
# 7             meat         pork     59

# %% [markdown]
# ## (2) Brand sales at online e-tailer

# %% [markdown]
# **(2.1) Import the dataset <code>fashion.csv</code>. Show the column names and their data types in this dataset.**

# %%
# put your code here
fashion_raw_df = pd.read_csv("../dataset/fashion.csv")
fashion_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                51 non-null     object
#  1   Amanda_Christensen  51 non-null     float64
#  2   Calvin_Klein        51 non-null     float64
#  3   Eton                51 non-null     float64
#  4   J_Lindeberg         51 non-null     float64
#  5   Lacoste             51 non-null     float64
#  6   Levi_s              22 non-null     float64
#  7   Oscar_Jacobson      51 non-null     float64
#  8   Ray_Ban             44 non-null     float64
#  9   Tiger_of_Sweden     51 non-null     float64
# dtypes: float64(9), object(1)
# memory usage: 4.1+ KB

# %% [markdown]
# **(2.2) Create a copy of the dataframe obtained in (2.1) and use it to complete the following tasks.**

# %%
# put your code here
fashion_df = fashion_raw_df.copy()

# %% [markdown]
# **(2.3) Remove columns with missing values and apply this change directly.**

# %%
# put your code here
fashion_df.drop(['Levi_s','Ray_Ban'], axis=1, inplace = True)

# %% [markdown]
# **(2.4) Extract the years from the column <code>Date</code> and put them in a new column named <code>Year</code>. Display the last 15 rows of the updated dataframe.**<br>
# Hint: To slice a substring from each element in the series, you can use <code>Series_name.str[start_index:stop_index]</code>
# https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html

# %%
# put your code here
fashion_df['Year'] = fashion_df.Date.str[0:4]
fashion_df.tail(15)
# Out:
#           Date  Amanda_Christensen  Calvin_Klein           Eton  \
# 36  2017-07-01         9184.310372   119238.3066  183610.606982
# 37  2017-08-01        12164.342400    85016.5580  204480.672509
# 38  2017-09-01        25773.145760    80580.4422  156046.625600
# 39  2017-10-01        46531.125920   103063.8309  157546.184436
# 40  2017-11-01        42064.348320   118070.1579  174829.909091
# 41  2017-12-01        46051.908760   161805.5756  260118.611564
# 42  2018-01-01        13380.797840   118475.8570  185989.177760
# 43  2018-02-01        11249.858680    61836.8515  149815.926618
# 44  2018-03-01        15495.021280    90790.3076  155274.442109
# 45  2018-04-01        16744.574000   118131.5499  214803.864509
# 46  2018-05-01        18392.313960   204984.4518  206474.623855
# 47  2018-06-01         8814.850040   166919.9272  182162.501745
# 48  2018-07-01        11251.049600   213309.2340  203603.248727
# 49  2018-08-01        18894.205920   126072.2828  160430.857018
# 50  2018-09-01        40879.207089   127294.3261  201055.575200
#
#       J_Lindeberg       Lacoste  Oscar_Jacobson  Tiger_of_Sweden  Year
# 36  161597.978831  118451.30520    76325.798880    359287.465160  2017
# 37  175047.646215   83573.79528    78230.467920    392753.100378  2017
# 38  301437.563446   69256.92424   110769.067413    198359.538147  2017
# 39  515773.468985   63033.54664   101160.592827    291117.520808  2017
# 40  370491.457231   75453.12564   110113.200373    251269.973504  2017
# 41  298335.176308  103456.62416   114198.896713    411577.376854  2017
# 42  267434.410092   75147.41728    94773.675369    278134.969293  2018
# 43  120719.771323   62896.21016    42654.850859    171890.186256  2018
# 44  175262.561231   78766.74850    71934.036240    188783.883675  2018
# 45  179687.701354  106144.59016   123740.466031    175034.787197  2018
# 46  203916.802462  220238.68144   116911.546540    233051.543938  2018
# 47  155347.746831  174421.28544    80526.395975    150157.636062  2018
# 48  232062.347015  116917.64056    73526.926100    222011.753474  2018
# 49  215516.890462   83220.94056   124228.859995    277055.473011  2018
# 50  331812.993231   92731.26152   145057.673813    303408.769829  2018

# %% [markdown]
# **(2.5) Select Tiger_of_Sweden's sales data in 2018 and store them in a new dataframe. The new dataframe should include the following columns: Date, Year, Tiger_of_Sweden.**<br>

# %%
# put your code here
tgs_df = fashion_df.loc[:,["Date","Year", "Tiger_of_Sweden"]][fashion_df.Year == '2018']
tgs_df
# Out:
#           Date  Year  Tiger_of_Sweden
# 42  2018-01-01  2018    278134.969293
# 43  2018-02-01  2018    171890.186256
# 44  2018-03-01  2018    188783.883675
# 45  2018-04-01  2018    175034.787197
# 46  2018-05-01  2018    233051.543938
# 47  2018-06-01  2018    150157.636062
# 48  2018-07-01  2018    222011.753474
# 49  2018-08-01  2018    277055.473011
# 50  2018-09-01  2018    303408.769829

# %% [markdown]
# **(2.6) Which month did Tiger_of_Sweden have the highest sales in 2018?**<br>

# %%
# put your code here
tgs_df.sort_values(by= "Tiger_of_Sweden", ascending = False)
# Answer: September
# Out:
#           Date  Year  Tiger_of_Sweden
# 50  2018-09-01  2018    303408.769829
# 42  2018-01-01  2018    278134.969293
# 49  2018-08-01  2018    277055.473011
# 46  2018-05-01  2018    233051.543938
# 48  2018-07-01  2018    222011.753474
# 44  2018-03-01  2018    188783.883675
# 45  2018-04-01  2018    175034.787197
# 43  2018-02-01  2018    171890.186256
# 47  2018-06-01  2018    150157.636062

# %% [markdown]
# ## (3) Complains
# In the US, 311 is a non-emergency phone number that people can call in many cities to find information about services, make complaints, or report problems like graffiti or road damage.

# %% [markdown]
# **(3.1) Import the dataset <code>complaints.csv</code>. Show the first 5 rows.**<br>
# Note: You may receive a warning message (https://pandas.pydata.org/docs/reference/api/pandas.errors.DtypeWarning.html). You can try to fix this little problem. If not, you can still continue with the following tasks.

# %%
# put your code here
complaints_df = pd.read_csv("../dataset/complaints.csv", dtype={'Incident Zip': object})  # or dtype={'Incident Zip': str}
complaints_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f91b49f868f3> in <module>
#       1 # put your code here
# ----> 2 complaints_df = pd.read_csv("../dataset/complaints.csv", dtype={'Incident Zip': object})  # or dtype={'Incident Zip': str}
#       3 complaints_df.head(5)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# **(3.2) Show the column names and their data types in this dataset.**

# %%
# put your code here
complaints_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111069 entries, 0 to 111068
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      111069 non-null  int64
#  1   Created Date                    111069 non-null  object
#  2   Closed Date                     60270 non-null   object
#  3   Agency                          111069 non-null  object
#  4   Agency Name                     111069 non-null  object
#  5   Complaint Type                  111069 non-null  object
#  6   Descriptor                      110613 non-null  object
#  7   Location Type                   79022 non-null   object
#  8   Incident Zip                    98807 non-null   object
#  9   Incident Address                84441 non-null   object
#  10  Street Name                     84432 non-null   object
#  11  Cross Street 1                  84728 non-null   object
#  12  Cross Street 2                  84005 non-null   object
#  13  Intersection Street 1           19364 non-null   object
#  14  Intersection Street 2           19366 non-null   object
#  15  Address Type                    102247 non-null  object
#  16  City                            98854 non-null   object
#  17  Landmark                        95 non-null      object
#  18  Facility Type                   19104 non-null   object
#  19  Status                          111069 non-null  object
#  20  Due Date                        39239 non-null   object
#  21  Resolution Action Updated Date  96507 non-null   object
#  22  Community Board                 111069 non-null  object
#  23  Borough                         111069 non-null  object
#  24  X Coordinate (State Plane)      98143 non-null   float64
#  25  Y Coordinate (State Plane)      98143 non-null   float64
#  26  Park Facility Name              111069 non-null  object
#  27  Park Borough                    111069 non-null  object
#  28  School Name                     111069 non-null  object
#  29  School Number                   111048 non-null  object
#  30  School Region                   110524 non-null  object
#  31  School Code                     110524 non-null  object
#  32  School Phone Number             111069 non-null  object
#  33  School Address                  111069 non-null  object
#  34  School City                     111069 non-null  object
#  35  School State                    111069 non-null  object
#  36  School Zip                      111069 non-null  object
#  37  School Not Found                38984 non-null   object
#  38  School or Citywide Complaint    0 non-null       float64
#  39  Vehicle Type                    99 non-null      object
#  40  Taxi Company Borough            117 non-null     object
#  41  Taxi Pick Up Location           1059 non-null    object
#  42  Bridge Highway Name             185 non-null     object
#  43  Bridge Highway Direction        185 non-null     object
#  44  Road Ramp                       180 non-null     object
#  45  Bridge Highway Segment          219 non-null     object
#  46  Garage Lot Name                 49 non-null      object
#  47  Ferry Direction                 24 non-null      object
#  48  Ferry Terminal Name             70 non-null      object
#  49  Latitude                        98143 non-null   float64
#  50  Longitude                       98143 non-null   float64
#  51  Location                        98143 non-null   object
# dtypes: float64(5), int64(1), object(46)
# memory usage: 44.1+ MB

# %% [markdown]
# **(3.3) How many observations and variables are there in this dataset?**

# %%
# put your code here
print("There are {} observations and {} variables in this dataset.".format(complaints_df.shape[0], complaints_df.shape[1]))
# Out:
# There are 111069 observations and 52 variables in this dataset.

# %% [markdown]
# **(3.4) Display the first five rows of columns <code>Complaint Type</code> and <code>Borough</code>.**

# %%
# put your code here
complaints_df.loc[:,['Complaint Type', 'Borough']].head(5)
# Out:
#             Complaint Type    Borough
# 0  Noise - Street/Sidewalk     QUEENS
# 1          Illegal Parking     QUEENS
# 2       Noise - Commercial  MANHATTAN
# 3          Noise - Vehicle  MANHATTAN
# 4                   Rodent  MANHATTAN

# %% [markdown]
# **(3.5) Show the number of complaints recorded in each region (borough).**<br>

# %%
# put your code here
complaints_df.Borough.value_counts()
# Out:
# BROOKLYN         32890
# MANHATTAN        24288
# QUEENS           22281
# BRONX            19686
# Unspecified       7107
# STATEN ISLAND     4817
# Name: Borough, dtype: int64

# %% [markdown]
# **(3.6) Create a subset of the MANHATTAN area named <code>manhattan_df</code> and include only columns <code>Complaint Type</code> and <code>Borough</code>.**

# %%
# put your code here
manhattan_df = complaints_df.loc[complaints_df.Borough == "MANHATTAN",['Complaint Type', 'Borough']]
manhattan_df
# Out:
#                  Complaint Type    Borough
# 2            Noise - Commercial  MANHATTAN
# 3               Noise - Vehicle  MANHATTAN
# 4                        Rodent  MANHATTAN
# 8            Noise - Commercial  MANHATTAN
# 11           Noise - Commercial  MANHATTAN
# ...                         ...        ...
# 111059  Noise - Street/Sidewalk  MANHATTAN
# 111060                    Noise  MANHATTAN
# 111062             Water System  MANHATTAN
# 111063             Water System  MANHATTAN
# 111066  Noise - Street/Sidewalk  MANHATTAN
#
# [24288 rows x 2 columns]

# %% [markdown]
# **(3.7) Import the dataset <code>complaints_mapping.xlsx</code>. Show the data.**<br>
# Hint: https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %%
# put your code here
complaints_type = pd.read_excel("../dataset/complaints_mapping.xlsx")
complaints_type
# Out:
#               Complaint Type    Category
# 0                    HEATING     Utility
# 1       GENERAL CONSTRUCTION     Utility
# 2     Street Light Condition     Traffic
# 3                   PLUMBING    Plumbing
# 4            PAINT - PLASTER    Graffiti
# 5           Blocked Driveway     Traffic
# 6                   NONCONST       Other
# 7           Street Condition     Traffic
# 8            Illegal Parking     Traffic
# 9                      Noise       Noise
# 10  Traffic Signal Condition     Traffic
# 11          Dirty Conditions  Sanitation
# 12              Water System     Utility
# 13        Noise - Commercial       Noise
# 14                  ELECTRIC     Utility
# 15         Broken Muni Meter     Utility
# 16   Noise - Street/Sidewalk       Noise
# 17      Sanitation Condition  Sanitation
# 18                    Rodent        Rats
# 19                     Sewer  Sanitation
# 20            Taxi Complaint     Traffic
# 21        Consumer Complaint    Consumer
# 22              Damaged Tree   Gardening
# 23   Overgrown Tree/Branches   Gardening
# 24                  Graffiti    Graffiti

# %% [markdown]
# **(3.8) Based on the dataframe obtained in (3.7), find the category of each complaint type in <code>manhattan_df</code>.**

# %%
# put your code here
pd.merge(manhattan_df, complaints_type, how = 'left', on = "Complaint Type")
# Out:
#                 Complaint Type    Borough Category
# 0           Noise - Commercial  MANHATTAN    Noise
# 1              Noise - Vehicle  MANHATTAN      NaN
# 2                       Rodent  MANHATTAN     Rats
# 3           Noise - Commercial  MANHATTAN    Noise
# 4           Noise - Commercial  MANHATTAN    Noise
# ...                        ...        ...      ...
# 24283  Noise - Street/Sidewalk  MANHATTAN    Noise
# 24284                    Noise  MANHATTAN    Noise
# 24285             Water System  MANHATTAN  Utility
# 24286             Water System  MANHATTAN  Utility
# 24287  Noise - Street/Sidewalk  MANHATTAN    Noise
#
# [24288 rows x 3 columns]

# %% [markdown]
# **(3.9) What are the five most common categories of complaints in Manhattan?.**

# %%
# put your code here
pd.merge(manhattan_df, complaints_type, how = 'left', on = "Complaint Type").Category.value_counts().head(5)
# Out:
# Utility     7433
# Traffic     4325
# Noise       3905
# Graffiti    1156
# Plumbing     961
# Name: Category, dtype: int64
